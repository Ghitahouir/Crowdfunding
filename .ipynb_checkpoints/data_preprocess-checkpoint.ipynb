# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import sys
import nltk

# %%
#loading the data
train_dataset = pd.read_json("Kickstarter_2022-12-15T03_20_04_521Z.json", lines=True)
actual_data = [train_dataset["data"][k] for k in range(len(train_dataset))]
train_dataset.head()
# Out:
#       table_id     robot_id                                run_id  \
# 0  Kickstarter  Kickstarter  Kickstarter_2022-12-15T03_20_04_521Z
# 1  Kickstarter  Kickstarter  Kickstarter_2022-12-15T03_20_04_521Z
# 2  Kickstarter  Kickstarter  Kickstarter_2022-12-15T03_20_04_521Z
# 3  Kickstarter  Kickstarter  Kickstarter_2022-12-15T03_20_04_521Z
# 4  Kickstarter  Kickstarter  Kickstarter_2022-12-15T03_20_04_521Z
#
#                                                 data
# 0  {'id': 2014941593, 'photo': {'key': 'assets/03...
# 1  {'id': 1932477189, 'photo': {'key': 'assets/03...
# 2  {'id': 1127603300, 'photo': {'key': 'assets/03...
# 3  {'id': 640015337, 'photo': {'key': 'assets/039...
# 4  {'id': 233782977, 'photo': {'key': 'assets/039...

# %%
#creating the dataset
train_data = pd.DataFrame(actual_data)
train_data.head()
# Out:
#            id                                              photo  \
# 0  2014941593  {'key': 'assets/038/408/400/93382a88c9dbc1af95...
# 1  1932477189  {'key': 'assets/039/331/847/6e37eed9904bea5a61...
# 2  1127603300  {'key': 'assets/039/363/407/a22ed33f3e39868214...
# 3   640015337  {'key': 'assets/039/441/179/34d28696f4d6b0e43c...
# 4   233782977  {'key': 'assets/039/379/732/36d936f41c46751a38...
#
#                                         name  \
# 0  Driving School Stories of Celebrity Teens
# 1       Crime Squad 3D Blu-ray - REMASTER3D!
# 2                Help Us Get To Los Angeles!
# 3                                     SECRET
# 4                          PINK (Short Film)
#
#                                                blurb    goal  pledged   state  \
# 0  Live camera installed inside an actual driving...  120000     26.0  failed
# 1  Crime Squad 3D in Superstereovision! Remastere...    2000   2541.0    live
# 2  As winners of the 48-Hour Film Project, we hop...   16000    106.0    live
# 3                                 A Superhero Comedy   50000    501.0    live
# 4  A neurotic actress falls into crisis at her bi...    2000   1176.0    live
#
#                                         slug  disable_communication country  \
# 0  driving-school-stories-of-celebrity-teens                  False      US
# 1                     crime-squad-3d-blu-ray                  False      GB
# 2     help-subharmonic-city-get-to-hollywood                  False      US
# 3                                   secret-0                  False      US
# 4                            pink-short-film                  False      US
#
#    ...                                           location  \
# 0  ...  {'id': 2363796, 'name': 'Beverly Hills', 'slug...
# 1  ...  {'id': 19344, 'name': 'Edinburgh', 'slug': 'ed...
# 2  ...  {'id': 2397816, 'name': 'El Paso', 'slug': 'el...
# 3  ...  {'id': 2416847, 'name': 'Hampton', 'slug': 'ha...
# 4  ...  {'id': 2379574, 'name': 'Chicago', 'slug': 'ch...
#
#                                             category  \
# 0  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 1  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 2  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 3  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 4  {'id': 292, 'name': 'Comedy', 'analytics_name'...
#
#                                              profile  spotlight  \
# 0  {'id': 4465571, 'project_id': 4465571, 'state'...      False
# 1  {'id': 4516474, 'project_id': 4516474, 'state'...      False
# 2  {'id': 4518603, 'project_id': 4518603, 'state'...      False
# 3  {'id': 4521089, 'project_id': 4521089, 'state'...      False
# 4  {'id': 4519929, 'project_id': 4519929, 'state'...      False
#
#                                                 urls  \
# 0  {'web': {'project': 'https://www.kickstarter.c...
# 1  {'web': {'project': 'https://www.kickstarter.c...
# 2  {'web': {'project': 'https://www.kickstarter.c...
# 3  {'web': {'project': 'https://www.kickstarter.c...
# 4  {'web': {'project': 'https://www.kickstarter.c...
#
#                                           source_url  friends  is_starred  \
# 0  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 1  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 2  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 3  https://www.kickstarter.com/discover/categorie...      NaN         NaN
# 4  https://www.kickstarter.com/discover/categorie...      NaN         NaN
#
#    is_backing  permissions
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 39 columns]

# %%
#exploring some of the features
print("The features of this dataset are: ", train_data.keys())
print(" \n \n blurb: ", train_data["blurb"][0], "\n \n ", "location: ", train_data["location"][0], "\n \n ", "category: ", train_data["category"][0], "\n \n ", "profile: ", train_data["profile"][0])
# Out:
# The features of this dataset are:  Index(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'country_displayable_name',
#        'currency', 'currency_symbol', 'currency_trailing_code', 'deadline',
#        'state_changed_at', 'created_at', 'launched_at', 'staff_pick',
#        'is_starrable', 'backers_count', 'static_usd_rate', 'usd_pledged',
#        'converted_pledged_amount', 'fx_rate', 'usd_exchange_rate',
#        'current_currency', 'usd_type', 'creator', 'location', 'category',
#        'profile', 'spotlight', 'urls', 'source_url', 'friends', 'is_starred',
#        'is_backing', 'permissions'],
#       dtype='object')
#
#
#  blurb:  Live camera installed inside an actual driving school
#
#   location:  {'id': 2363796, 'name': 'Beverly Hills', 'slug': 'beverly-hills-ca', 'short_name': 'Beverly Hills, CA', 'displayable_name': 'Beverly Hills, CA', 'localized_name': 'Beverly Hills', 'country': 'US', 'state': 'CA', 'type': 'Town', 'is_root': False, 'expanded_country': 'United States', 'urls': {'web': {'discover': 'https://www.kickstarter.com/discover/places/beverly-hills-ca', 'location': 'https://www.kickstarter.com/locations/beverly-hills-ca'}, 'api': {'nearby_projects': 'https://api.kickstarter.com/v1/discover?signature=1671131424.7dadba4f2fadc4b0b45e3bfce93a67975f2789a9&woe_id=2363796'}}}
#
#   category:  {'id': 292, 'name': 'Comedy', 'analytics_name': 'Comedy', 'slug': 'film & video/comedy', 'position': 3, 'parent_id': 11, 'parent_name': 'Film & Video', 'color': 16734574, 'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/film%20&%20video/comedy'}}}
#
#   profile:  {'id': 4465571, 'project_id': 4465571, 'state': 'inactive', 'state_changed_at': 1661625074, 'name': None, 'blurb': None, 'background_color': None, 'text_color': None, 'link_background_color': None, 'link_text_color': None, 'link_text': None, 'link_url': None, 'show_feature_image': False, 'background_image_opacity': 0.8, 'should_show_feature_image_section': True, 'feature_image_attributes': {'image_urls': {'default': 'https://ksr-ugc.imgix.net/assets/038/408/400/93382a88c9dbc1af95992c496abd38e7_original.jpeg?ixlib=rb-4.0.2&crop=faces&w=1552&h=873&fit=crop&v=1661625239&auto=format&frame=1&q=92&s=04b08346a71d90b32a7cbb28be0972c2', 'baseball_card': 'https://ksr-ugc.imgix.net/assets/038/408/400/93382a88c9dbc1af95992c496abd38e7_original.jpeg?ixlib=rb-4.0.2&crop=faces&w=560&h=315&fit=crop&v=1661625239&auto=format&frame=1&q=92&s=c8db7a1b2282afbd6c85813346d69682'}}}

# %%
#writing a function to create the final dataset
def clean_concat(list_of_datasets):
    data_frames=[]
    for dataset in list_of_datasets:
        dataset = pd.read_json(dataset, lines=True)
        actual_data = [dataset["data"][k] for k in range(len(dataset))]
        data_frames.append(pd.DataFrame(actual_data))
    final_dataset = pd.concat([data for data in data_frames])
    return(final_dataset)

# %%
# concatenating creates problems with the indexes 
#training_df = clean_concat(["/Users/ghitaalami/Coding Projects/Berkeley Projects/ML-and-Data-Analytics/Project/Kickstarter_2022-12-15T03_20_04_521Z.json", "/Users/ghitaalami/Coding Projects/Berkeley Projects/ML-and-Data-Analytics/Project/Kickstarter_2023-01-05T03_20_04_136Z.json"])

# %%
training_df = train_data

# %%
#let's decide which columns should be dropped
training_df["photo"][0] #should probably be dropped for now
training_df["state"][0] #our label 
training_df["urls"][0] #should probably be dropped 
training_df["currency"][10] #should be dropped because "currency_symbol" contains the same information
training_df["source_url"][200] #should probably be dropped for now 
training_df["friends"][1600] #should check if only contains NaNs
training_df["permissions"][1000] #should check if only contains NaNs
# Out:
# nan

# %%
#modify the clean_concat function to drop some columns
def clean_concat_drop(list_of_datasets, list_of_columns):
    data_frames=[]
    for dataset in list_of_datasets:
        dataset = pd.read_json(dataset, lines=True)
        actual_data = [dataset["data"][k] for k in range(len(dataset))]
        data_frames.append(pd.DataFrame(actual_data))
    final_dataset = pd.concat([data for data in data_frames])
    final_dataset = final_dataset.drop(list_of_columns)
    return(final_dataset)

# %%
#dropping some useless features for now
training_df = training_df.drop(["photo", "urls", "currency", "source_url" ], axis=1)

# %%
training_df["profile"][0]
# Out:
# {'id': 4465571,
#  'project_id': 4465571,
#  'state': 'inactive',
#  'state_changed_at': 1661625074,
#  'name': None,
#  'blurb': None,
#  'background_color': None,
#  'text_color': None,
#  'link_background_color': None,
#  'link_text_color': None,
#  'link_text': None,
#  'link_url': None,
#  'show_feature_image': False,
#  'background_image_opacity': 0.8,
#  'should_show_feature_image_section': True,
#  'feature_image_attributes': {'image_urls': {'default': 'https://ksr-ugc.imgix.net/assets/038/408/400/93382a88c9dbc1af95992c496abd38e7_original.jpeg?ixlib=rb-4.0.2&crop=faces&w=1552&h=873&fit=crop&v=1661625239&auto=format&frame=1&q=92&s=04b08346a71d90b32a7cbb28be0972c2',
#    'baseball_card': 'https://ksr-ugc.imgix.net/assets/038/408/400/93382a88c9dbc1af95992c496abd38e7_original.jpeg?ixlib=rb-4.0.2&crop=faces&w=560&h=315&fit=crop&v=1661625239&auto=format&frame=1&q=92&s=c8db7a1b2282afbd6c85813346d69682'}}}

# %%
#Let's try a first model with less features
training_df = training_df.drop("country_displayable_name", axis=1)
training_df = training_df.drop(["is_backing", "is_starred", "spotlight", "friends", "permissions", "disable_communication"], axis=1)

# %%
training_df.head(5)
# Out:
#            id                                       name  \
# 0  2014941593  Driving School Stories of Celebrity Teens
# 1  1932477189       Crime Squad 3D Blu-ray - REMASTER3D!
# 2  1127603300                Help Us Get To Los Angeles!
# 3   640015337                                     SECRET
# 4   233782977                          PINK (Short Film)
#
#                                                blurb    goal  pledged   state  \
# 0  Live camera installed inside an actual driving...  120000     26.0  failed
# 1  Crime Squad 3D in Superstereovision! Remastere...    2000   2541.0    live
# 2  As winners of the 48-Hour Film Project, we hop...   16000    106.0    live
# 3                                 A Superhero Comedy   50000    501.0    live
# 4  A neurotic actress falls into crisis at her bi...    2000   1176.0    live
#
#                                         slug country currency_symbol  \
# 0  driving-school-stories-of-celebrity-teens      US               $
# 1                     crime-squad-3d-blu-ray      GB               £
# 2     help-subharmonic-city-get-to-hollywood      US               $
# 3                                   secret-0      US               $
# 4                            pink-short-film      US               $
#
#    currency_trailing_code  ...    usd_pledged  converted_pledged_amount  \
# 0                    True  ...           26.0                      26.0
# 1                   False  ...  3082.93718733                    3137.0
# 2                    True  ...          106.0                     106.0
# 3                    True  ...          501.0                     501.0
# 4                    True  ...         1176.0                    1176.0
#
#     fx_rate  usd_exchange_rate  current_currency       usd_type  \
# 0  1.000000           1.000000               USD  international
# 1  1.234778           1.234778               USD  international
# 2  1.000000           1.000000               USD  international
# 3  1.000000           1.000000               USD  international
# 4  1.000000           1.000000               USD  international
#
#                                              creator  \
# 0  {'id': 1097743720, 'name': 'Kamran Rafizadeh F...
# 1  {'id': 115821324, 'name': 'Andrew Murchie', 's...
# 2  {'id': 475346952, 'name': 'Subharmonic City Pr...
# 3  {'id': 66032665, 'name': 'Brian Cutter', 'slug...
# 4  {'id': 1827951120, 'name': 'Jackson Cook', 'sl...
#
#                                             location  \
# 0  {'id': 2363796, 'name': 'Beverly Hills', 'slug...
# 1  {'id': 19344, 'name': 'Edinburgh', 'slug': 'ed...
# 2  {'id': 2397816, 'name': 'El Paso', 'slug': 'el...
# 3  {'id': 2416847, 'name': 'Hampton', 'slug': 'ha...
# 4  {'id': 2379574, 'name': 'Chicago', 'slug': 'ch...
#
#                                             category  \
# 0  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 1  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 2  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 3  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 4  {'id': 292, 'name': 'Comedy', 'analytics_name'...
#
#                                              profile
# 0  {'id': 4465571, 'project_id': 4465571, 'state'...
# 1  {'id': 4516474, 'project_id': 4516474, 'state'...
# 2  {'id': 4518603, 'project_id': 4518603, 'state'...
# 3  {'id': 4521089, 'project_id': 4521089, 'state'...
# 4  {'id': 4519929, 'project_id': 4519929, 'state'...
#
# [5 rows x 28 columns]

# %%
#only keeping the name of the city in the location
training_df["location"] = [training_df["location"][k]["name"] if type(training_df["location"][k]) is dict else 'nan' for k in range(len(training_df)) ]
training_df.head(5)
# Out:
#            id                                       name  \
# 0  2014941593  Driving School Stories of Celebrity Teens
# 1  1932477189       Crime Squad 3D Blu-ray - REMASTER3D!
# 2  1127603300                Help Us Get To Los Angeles!
# 3   640015337                                     SECRET
# 4   233782977                          PINK (Short Film)
#
#                                                blurb    goal  pledged   state  \
# 0  Live camera installed inside an actual driving...  120000     26.0  failed
# 1  Crime Squad 3D in Superstereovision! Remastere...    2000   2541.0    live
# 2  As winners of the 48-Hour Film Project, we hop...   16000    106.0    live
# 3                                 A Superhero Comedy   50000    501.0    live
# 4  A neurotic actress falls into crisis at her bi...    2000   1176.0    live
#
#                                         slug country currency_symbol  \
# 0  driving-school-stories-of-celebrity-teens      US               $
# 1                     crime-squad-3d-blu-ray      GB               £
# 2     help-subharmonic-city-get-to-hollywood      US               $
# 3                                   secret-0      US               $
# 4                            pink-short-film      US               $
#
#    currency_trailing_code  ...    usd_pledged  converted_pledged_amount  \
# 0                    True  ...           26.0                      26.0
# 1                   False  ...  3082.93718733                    3137.0
# 2                    True  ...          106.0                     106.0
# 3                    True  ...          501.0                     501.0
# 4                    True  ...         1176.0                    1176.0
#
#     fx_rate  usd_exchange_rate  current_currency       usd_type  \
# 0  1.000000           1.000000               USD  international
# 1  1.234778           1.234778               USD  international
# 2  1.000000           1.000000               USD  international
# 3  1.000000           1.000000               USD  international
# 4  1.000000           1.000000               USD  international
#
#                                              creator       location  \
# 0  {'id': 1097743720, 'name': 'Kamran Rafizadeh F...  Beverly Hills
# 1  {'id': 115821324, 'name': 'Andrew Murchie', 's...      Edinburgh
# 2  {'id': 475346952, 'name': 'Subharmonic City Pr...        El Paso
# 3  {'id': 66032665, 'name': 'Brian Cutter', 'slug...        Hampton
# 4  {'id': 1827951120, 'name': 'Jackson Cook', 'sl...        Chicago
#
#                                             category  \
# 0  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 1  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 2  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 3  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 4  {'id': 292, 'name': 'Comedy', 'analytics_name'...
#
#                                              profile
# 0  {'id': 4465571, 'project_id': 4465571, 'state'...
# 1  {'id': 4516474, 'project_id': 4516474, 'state'...
# 2  {'id': 4518603, 'project_id': 4518603, 'state'...
# 3  {'id': 4521089, 'project_id': 4521089, 'state'...
# 4  {'id': 4519929, 'project_id': 4519929, 'state'...
#
# [5 rows x 28 columns]

# %%
import json

# convert the 'profile' column to a string representation of the dictionary
training_df['profile_str'] = training_df['profile'].apply(json.dumps)

# group the dataframe by the creator id and get all the project ids associated with them
previous_launchers = training_df.groupby('profile_str')['id'].apply(list)

# create a dictionary to map project ids to creator ids
project_to_creator = training_df.set_index('id')['profile'].apply(lambda x: x['id']).to_dict()

# create a new column that checks if the creator has launched any other projects
training_df['previous_launcher'] = training_df['id'].apply(lambda x: True if project_to_creator[x] in previous_launchers.values else False)

# drop the temporary 'profile_str' column
training_df = training_df.drop('profile_str', axis=1)

# %%
training_df["creator"][0]
# Out:
# {'id': 1097743720,
#  'name': 'Kamran Rafizadeh Ford',
#  'is_registered': None,
#  'is_email_verified': None,
#  'chosen_currency': None,
#  'is_superbacker': None,
#  'avatar': {'thumb': 'https://ksr-ugc.imgix.net/assets/038/408/529/23acdbc7721f02dd0bcf7b37b0097774_original.jpg?ixlib=rb-4.0.2&w=40&h=40&fit=crop&v=1661626266&auto=format&frame=1&q=92&s=19aff20078bdd94e2b86be2d1d7ff47b',
#   'small': 'https://ksr-ugc.imgix.net/assets/038/408/529/23acdbc7721f02dd0bcf7b37b0097774_original.jpg?ixlib=rb-4.0.2&w=80&h=80&fit=crop&v=1661626266&auto=format&frame=1&q=92&s=3695cd52b441223414a2244976e991a7',
#   'medium': 'https://ksr-ugc.imgix.net/assets/038/408/529/23acdbc7721f02dd0bcf7b37b0097774_original.jpg?ixlib=rb-4.0.2&w=160&h=160&fit=crop&v=1661626266&auto=format&frame=1&q=92&s=a41a7bcd1de8422fa77da0e86802878d'},
#  'urls': {'web': {'user': 'https://www.kickstarter.com/profile/1097743720'},
#   'api': {'user': 'https://api.kickstarter.com/v1/users/1097743720?signature=1671160818.65e537e0b50125612280cc2d011ad950f163b28b'}}}

# %%
# extract 'name' and 'is_superbacker' from the 'creator' column
training_df['is_superbacker'] = training_df['creator'].apply(lambda x: x.get('is_superbacker'))
training_df['creator'] = training_df['creator'].apply(lambda x: x.get('name'))

# %%
training_df['pledge_per_backer'] = np.where(training_df['backers_count'] == 0, 0, training_df['pledged'] / training_df['backers_count'])
training_df = training_df.drop(['pledged', 'backers_count', 'currency_trailing_code'], axis=1)

# %%
training_df = training_df.drop([ 'is_starrable'], axis=1)

# %%
training_df = training_df.drop([ 'fx_rate'], axis=1)

# %%
#convert the goal to USD
training_df['goal_usd'] = training_df['goal'] * training_df['static_usd_rate']
training_df['goal_usd'] = training_df['goal_usd'].astype(float)
training_df['usd_pledged'] = training_df['usd_pledged'].astype(float)

# %%
#percentage of success of the campaign
training_df['percentage of success'] = (training_df['usd_pledged'] / training_df['goal_usd']) * 100

# %%
training_df['original_currency'] = training_df['currency_symbol']
training_df = training_df.drop(['currency_symbol'], axis = 1)

# %%
training_df.head()
# Out:
#            id                                       name  \
# 0  2014941593  Driving School Stories of Celebrity Teens
# 1  1932477189       Crime Squad 3D Blu-ray - REMASTER3D!
# 2  1127603300                Help Us Get To Los Angeles!
# 3   640015337                                     SECRET
# 4   233782977                          PINK (Short Film)
#
#                                                blurb    goal   state  \
# 0  Live camera installed inside an actual driving...  120000  failed
# 1  Crime Squad 3D in Superstereovision! Remastere...    2000    live
# 2  As winners of the 48-Hour Film Project, we hop...   16000    live
# 3                                 A Superhero Comedy   50000    live
# 4  A neurotic actress falls into crisis at her bi...    2000    live
#
#                                         slug country    deadline  \
# 0  driving-school-stories-of-celebrity-teens      US  1671048120
# 1                     crime-squad-3d-blu-ray      GB  1673087556
# 2     help-subharmonic-city-get-to-hollywood      US  1675634857
# 3                                   secret-0      US  1675519162
# 4                            pink-short-film      US  1672725540
#
#    state_changed_at  created_at  ...                       creator  \
# 0        1671048122  1661625074  ...         Kamran Rafizadeh Ford
# 1        1670495559  1669548519  ...                Andrew Murchie
# 2        1670450860  1669840906  ...  Subharmonic City Productions
# 3        1670335164  1670252610  ...                  Brian Cutter
# 4        1670035783  1670028130  ...                  Jackson Cook
#
#         location                                           category  \
# 0  Beverly Hills  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 1      Edinburgh  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 2        El Paso  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 3        Hampton  {'id': 292, 'name': 'Comedy', 'analytics_name'...
# 4        Chicago  {'id': 292, 'name': 'Comedy', 'analytics_name'...
#
#                                              profile  previous_launcher  \
# 0  {'id': 4465571, 'project_id': 4465571, 'state'...              False
# 1  {'id': 4516474, 'project_id': 4516474, 'state'...              False
# 2  {'id': 4518603, 'project_id': 4518603, 'state'...              False
# 3  {'id': 4521089, 'project_id': 4521089, 'state'...              False
# 4  {'id': 4519929, 'project_id': 4519929, 'state'...              False
#
#    is_superbacker pledge_per_backer      goal_usd percentage of success  \
# 0            None         13.000000  120000.00000              0.021667
# 1            None         43.810345    2426.55426            127.050000
# 2            None         21.200000   16000.00000              0.662500
# 3            None        250.500000   50000.00000              1.002000
# 4            None        106.909091    2000.00000             58.800000
#
#   original_currency
# 0                 $
# 1                 £
# 2                 $
# 3                 $
# 4                 $
#
# [5 rows x 28 columns]

# %%
training_df.columns
# Out:
# Index(['id', 'name', 'blurb', 'goal', 'state', 'slug', 'country', 'deadline',
#        'state_changed_at', 'created_at', 'launched_at', 'staff_pick',
#        'static_usd_rate', 'usd_pledged', 'converted_pledged_amount',
#        'usd_exchange_rate', 'current_currency', 'usd_type', 'creator',
#        'location', 'category', 'profile', 'previous_launcher',
#        'is_superbacker', 'pledge_per_backer', 'goal_usd',
#        'percentage of success', 'original_currency'],
#       dtype='object')

# %%
training_df = training_df.drop([ 'profile', 'state_changed_at', 'static_usd_rate', 'converted_pledged_amount', 'usd_exchange_rate', 'current_currency', 'usd_type'], axis=1)

# %%
# extract 'slug' and 'color' from category and create new columns
training_df['campaign_color'] = training_df['category'].apply(lambda x: x['color'])
training_df['category'] = training_df['category'].apply(lambda x: x['slug'])

# %%
training_df.columns
# Out:
# Index(['id', 'name', 'blurb', 'goal', 'state', 'slug', 'country', 'deadline',
#        'created_at', 'launched_at', 'staff_pick', 'usd_pledged', 'creator',
#        'location', 'category', 'previous_launcher', 'is_superbacker',
#        'pledge_per_backer', 'goal_usd', 'percentage of success',
#        'original_currency', 'campaign_color'],
#       dtype='object')

# %%
# perform lemmatization, stemming, remove_stopwords, tokenization on the texts remaining
# gather all the texts in one column ({location: 'Paris' , category: 'comedy'} become {text: 'location_Paris, category_comedy'} for example)
# fit a classification model on the resulting dataset

# %% [markdown]
# ### Changing to lowercase, remove punctuation, digits, make slug nicer, etc

# %%
training_df['slug'] = training_df['slug'].apply(lambda x: x.replace("-", " " ))

# %%
training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']] = training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']].applymap(str.lower)

# %%
#Remove Punctations 
from string import punctuation

#You can get this function from our discussion session code. However, we leave it as a blank for a practice.
def remove_punctuation(document):

    no_punct = ''.join([character for character in document if character not in punctuation])
    
    return no_punct

training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']] = training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']].applymap(remove_punctuation)

#Remove Digits 

def remove_digit(document): 
    
    no_digit = ''.join([character for character in document if not character.isdigit()])
              
    return no_digit

training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']] = training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']].applymap(remove_digit)

# %% [markdown]
# ### Tokenization, remove stopwords and combine into one text column

# %%
#Tokenize

from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']] = training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']].applymap(word_tokenize)

#Remove Stopwords

from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_stopwords(document):
    
    words = [word for word in document if not word in stop_words]
    
    return words

training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']] = training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']].applymap(remove_stopwords)

#We use porter stemming 

from nltk.stem import PorterStemmer

porter = PorterStemmer()

def stemmer(document):
    
    stemmed_document = [porter.stem(word) for word in document]
    
    return stemmed_document

training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']]= training_df[['name','blurb','slug', 'country', 'creator', 'location', 'category']].applymap(stemmer)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/zackbrodtman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zackbrodtman/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def add_name(document):
    
    added_document = [x + str('_name') for x in document]
    
    return added_document

def add_blurb(document):
    
    added_document = [x + str('_blurb') for x in document]
    
    return added_document

def add_slug(document):
    
    added_document = [x + str('_slug') for x in document]
    
    return added_document

def add_country(document):
    
    added_document = [x + str('_country') for x in document]
    
    return added_document

def add_location(document):
    
    added_document = [x + str('_location') for x in document]
    
    return added_document

def add_category(document):
    
    added_document = [x + str('_category') for x in document]
    
    return added_document

training_df['name'] = training_df['name'].apply(add_name)
training_df['blurb'] = training_df['blurb'].apply(add_blurb)
training_df['slug'] = training_df['slug'].apply(add_slug)
training_df['country'] = training_df['country'].apply(add_country)
training_df['location'] = training_df['location'].apply(add_location)
training_df['category'] = training_df['category'].apply(add_category)

#Now we need to merge all those columns into a single column
training_df['text'] = training_df['name'] + training_df['blurb'] + training_df['slug'] + training_df['country'] + training_df['location'] + training_df['category']

# %%
training_df = training_df.drop(['name','blurb','slug', 'country', 'creator', 'location', 'category'], axis = 1)
# Out:
#               id    goal       state    deadline  created_at  launched_at  \
# 0     2014941593  120000      failed  1671048120  1661625074   1670554364
# 1     1932477189    2000        live  1673087556  1669548519   1670495556
# 2     1127603300   16000        live  1675634857  1669840906   1670450857
# 3      640015337   50000        live  1675519162  1670252610   1670335162
# 4      233782977    2000        live  1672725540  1670028130   1670035781
# ...          ...     ...         ...         ...         ...          ...
# 7985   914698124   10000  successful  1586653200  1583888243   1584123089
# 7986   737874975    1500  successful  1586645343  1561763985   1584053343
# 7987  2130813092   15000  successful  1586525403  1582486966   1583933403
# 7988   679682143     500  successful  1586476803  1581595491   1583884803
# 7989  1257466408    1000  successful  1585605331  1583792427   1583877331
#
#       staff_pick   usd_pledged  previous_launcher is_superbacker  \
# 0          False     26.000000              False           None
# 1          False   3082.937187              False           None
# 2          False    106.000000              False           None
# 3          False    501.000000              False           None
# 4          False   1176.000000              False           None
# ...          ...           ...                ...            ...
# 7985        True  15752.000000              False           None
# 7986       False    981.927772              False           None
# 7987        True  16806.700000              False           None
# 7988        True   3054.004221              False           None
# 7989       False   1317.000000              False           None
#
#       pledge_per_backer       goal_usd  percentage of success  \
# 0             13.000000  120000.000000               0.021667
# 1             43.810345    2426.554260             127.050000
# 2             21.200000   16000.000000               0.662500
# 3            250.500000   50000.000000               1.002000
# 4            106.909091    2000.000000              58.800000
# ...                 ...            ...                    ...
# 7985          41.452632   10000.000000             157.520000
# 7986          53.832857     977.159235             100.488000
# 7987          50.622590   15000.000000             112.044667
# 7988          21.822430     653.962360             467.000000
# 7989          36.583333    1000.000000             131.700000
#
#      original_currency  campaign_color  \
# 0                    $        16734574
# 1                    £        16734574
# 2                    $        16734574
# 3                    $        16734574
# 4                    $        16734574
# ...                ...             ...
# 7985                 $        16776056
# 7986                 $        16776056
# 7987                 $        16776056
# 7988                 £        16776056
# 7989                 $        16776056
#
#                                                    text
# 0     [drive_name, school_name, stori_name, celebr_n...
# 1     [crime_name, squad_name, bluray_name, remaster...
# 2     [help_name, us_name, get_name, lo_name, angel_...
# 3     [secret_name, superhero_blurb, comedi_blurb, s...
# 4     [pink_name, short_name, film_name, neurot_blur...
# ...                                                 ...
# 7985  [fairi_name, boy_name, graphic_blurb, novel_bl...
# 7986  [crucifix_name, execution_name, epic_name, hr_...
# 7987  [ghost_name, gulag_name, vol_name, continu_blu...
# 7988  [your_name, stuck_name, romant_blurb, comedi_b...
# 7989  [dino_name, beast_name, book_name, reckon_blur...
#
# [7990 rows x 16 columns]
